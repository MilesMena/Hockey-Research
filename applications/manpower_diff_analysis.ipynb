# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# (50277, 29)

# %%
df = pd.read_csv("Subset_Hockey_Data.csv")
plt.style.use("ggplot")
#df["Manpower Diff"].unique()
df.shape

# %%
# What we are tyring to do is to look at specific games and matching the states, see if the probability is the same or different
# Instead of checking a single game we could go straight to the probabilities.
f1 = open("fprint_manpower.txt","w")
# print every second, the states 0,5,5 and then 0,4,4
for i in range(0,3600,60):
    #f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(10) + "("  + str(i) + ")" + ")") #(0,5,5)
    #f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(5) + "("  + str(i) + ")" + ")") #(0,4,4)
    #f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(1) + "("  + str(i) + ")" + ")") # (0,3,3)
    #f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(13) + "("  + str(i) + ")" + ")") # (0,6,5)
    f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(11) + "("  + str(i) + ")" + ")") # (0,5,6)
f1.write("\n" + " ")
for i in range(0,3600,60):
    #f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(9) + "("  + str(i) + ")" + ")") #(0,5,4)
    f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(6) + "("  + str(i) + ")" + ")") # (0,4,5)
f1.write("\n" + " ")
for i in range(0,3600,60):
    #f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(4) + "("  + str(i) + ")" + ")") #(0,4,3)
    f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(2) + "("  + str(i) + ")" + ")") # (0,3,4)
f1.write("\n" + " ")
for i in range(0,3600,60):
    f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(12) + "("  + str(i) + ")" + ")") # (0,6,4)
f1.write("\n" + " ")
for i in range(0,3600,60):
    f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(8) + "("  + str(i) + ")" + ")") # (0,5,3)
f1.write("\n" + " ")
for i in range(0,3600,60):
    f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(7) + "("  + str(i) + ")" + ")") # (0,4,6)
f1.write("\n" + " ")
for i in range(0,3600,60):
    f1.write("\n" + "fprintf('" + str(i) + "\\t%2.15f\\n'," + "col" +  str(3) + "("  + str(i) + ")" + ")") # (0,3,5)
f1.write("\n" + " ")
f1.close()

# %%
# Create the text file for Harvey to run.
f3 = open("harveyHockey_p1.txt","r")
f4 = open("col_printer.txt","r")
f5 = open("fprint_manpower.txt","r")
f6 = open("HockeyGameMatlab.txt", "w")
lines3 = f3.readlines()
for line in lines3:
    f6.write(line)
lines4 = f4.readlines()
for line in lines4:
    f6.write(line)
lines5 = f5.readlines()
for line in lines5:
    f6.write(line)
f3.close()
f4.close()
f5.close()
f6.close()

# %%
# df where mandiff == 0
# Currently it contains extra rows, but removing would remove the correct time of the state change

df_man_0 = df.loc[(df["Manpower Diff"] == 0)]
a = 1
game = 20000 + a
df_compare_game = pd.DataFrame()
df_compare_game[["g1_tState","g1_time"]] = df_man_0.loc[df_man_0["game_id"] == game][["TransitionState","time"]].reset_index(drop = True)
df_compare_game[["g2_tState","g2_time"]] = df_man_0.loc[df_man_0["game_id"] == game + 1][["TransitionState","time"]].reset_index(drop = True)
#print(df_man.shape)
#df_man_0.head()
df_compare_game.head(20)
#df_man_0.groupby(by = ["game_id"])




# Not a bad idea, but we would have to get super lucky with the games we pick. 
# Try to automate the search for similiar TranstionState at approximately the same time.
#df_game1 = df_man_0.loc[df["game_id"] == 20300][["TransitionState", "time"]].reset_index(drop = True)
#df_game2 = df_man_0.loc[df["game_id"] == 20030][["TransitionState","time"]].reset_index(drop = True)
#print(df_game1)
#print(df_game2)
# Out:
#    g1_tState  g1_time g2_tState  g2_time
# 0      0,5,5        0     0,5,5      0.0
# 1      0,5,5       74     0,5,5    241.0
# 2     -1,4,4      603     1,5,5    246.0
# 3      0,4,4      608     1,5,5    666.0
# 4      0,5,5      723     1,4,4    883.0
# 5      0,5,5      763     1,5,5   1003.0
# 6      1,5,5      834     1,5,5   1013.0
# 7      1,5,5      979     1,5,5   1175.0
# 8      1,5,5      999     1,5,5   1366.0
# 9      1,5,5     1145     1,5,5   1399.0
# 10     1,5,5     1156     1,5,5   1413.0
# 11     1,5,5     1239     1,5,5   1422.0
# 12     1,5,5     1366     1,5,5   1461.0
# 13     1,5,5     1367     1,5,5   1708.0
# 14     1,5,5     1422     1,5,5   1789.0
# 15     1,5,5     1433     0,5,5   1830.0
# 16     1,5,5     1462     1,5,5   2114.0
# 17     1,5,5     1512     1,4,4   2400.0
# 18     1,5,5     1611    -1,5,5   2727.0
# 19     1,5,5     1618    -1,5,5   2796.0

# %%
# if you need to print multiple probs then change name of time[] and prob[]
# State == (0,5,5,t)
f7 = open("winID_10_prob.txt","r")
time = []
prob = []
lines7 = f7.readlines()
for line in lines7:
    parts = line.split("\t")
    time.append(int(parts[0]))
    prob.append(float(parts[1].replace(" ", "").strip("\n")))
# State == (0,4,4,t)
f8 = open("winID_5_prob.txt","r")
time2 = []
prob2 = []
lines8 = f8.readlines()
for line in lines8:
    parts1 = line.split("\t")
    time2.append(int(parts1[0]))
    prob2.append(float(parts1[1].replace(" ", "").strip("\n")))
# State == (0,3,3,t)
f9 = open("winID_1_prob.txt","r")
time3 = []
prob3 = []
lines9 = f9.readlines()
for line in lines9:
    parts2 = line.split("\t")
    time3.append(int(parts2[0]))
    prob3.append(float(parts2[1].replace(" ", "").strip("\n")))

# %%
# State == (0,6,5,t)
f10 = open("winID_13_prob.txt","r")
time4 = []
prob4 = []
lines10 = f10.readlines()
for line in lines10:
    parts3 = line.split("\t")
    time4.append(int(parts3[0]))
    prob4.append(float(parts3[1].replace(" ", "").strip("\n")))
# state == (0,5,4,t)
f11 = open("winID_9_prob.txt","r")
time5 = []
prob5 = []
lines11 = f11.readlines()
for line in lines11:
    parts4 = line.split("\t")
    time5.append(int(parts4[0]))
    prob5.append(float(parts4[1].replace(" ", "").strip("\n"))) 
#state == (0,4,3,t)
f12 = open("winID_4_prob.txt","r")
time6 = []
prob6 = []
lines12 = f12.readlines()
for line in lines12:
    parts5 = line.split("\t")
    time6.append(int(parts5[0]))
    prob6.append(float(parts5[1].replace(" ", "").strip("\n")))

# %%
# State == (0,5,6,t)
f13 = open("winID_11_prob.txt","r")
time7 = []
prob7 = []
lines13 = f13.readlines()
for line in lines13:
    parts6 = line.split("\t")
    time7.append(int(parts6[0]))
    prob7.append(float(parts6[1].replace(" ", "").strip("\n")))
# state == (0,4,5,t)
f14 = open("winID_6_prob.txt","r")
time8 = []
prob8 = []
lines14 = f14.readlines()
for line in lines14:
    parts100 = line.split("\t")
    time8.append(int(parts100[0]))
    prob8.append(float(parts100[1].replace(" ", "").strip("\n"))) 
#state == (0,3,4,t)
f15 = open("winID_2_prob.txt","r")
time9 = []
prob9 = []
lines15 = f15.readlines()
for line in lines15:
    parts7 = line.split("\t")
    time9.append(int(parts7[0]))
    prob9.append(float(parts7[1].replace(" ", "").strip("\n")))

# %%
# state == (0,6,4,t)
f16 = open("winID_12_prob.txt","r")
time10 = []
prob10 = []
lines16 = f16.readlines()
for line in lines16:
    parts8 = line.split("\t")
    time10.append(int(parts8[0]))
    prob10.append(float(parts8[1].replace(" ", "").strip("\n"))) 
#state == (0,5,3,t)
f17 = open("winID_8_prob.txt","r")
time11 = []
prob11 = []
lines17 = f17.readlines()
for line in lines17:
    parts9 = line.split("\t")
    time11.append(int(parts9[0]))
    prob11.append(float(parts9[1].replace(" ", "").strip("\n")))

# %%
# state == (0,4,6,t)
f18 = open("winID_7_prob.txt","r")
time12 = []
prob12 = []
lines18 = f18.readlines()
for line in lines18:
    parts10 = line.split("\t")
    time12.append(int(parts10[0]))
    prob12.append(float(parts10[1].replace(" ", "").strip("\n")))
#state == (0,3,5,t)
f19 = open("winID_8_prob.txt","r")
time13 = []
prob13 = []
lines19 = f19.readlines()
for line in lines19:
    parts11 = line.split("\t")
    time13.append(int(parts11[0]))
    prob13.append(float(parts11[1].replace(" ", "").strip("\n")))

# %%
# Data frame of prob and time
# Scale the axis so differences can be compared.
d1 = {"time":time,"(0,5,5,t)": prob}
d2 = {"time": time2, "(0,4,4,t)": prob2}
d3 = {"time": time3, "(0,3,3,t)":prob3}
d4 = {"time": time4, "(0,6,5,t)":prob4}
d5 = {"time": time5, "(0,5,4,t)":prob5}
d6 = {"time": time6, "(0,4,3,t)":prob6}
d7 = {"time": time7, "(0,5,6,t)":prob7}
d8 = {"time": time8, "(0,4,5,t)":prob8}
d9 = {"time": time9, "(0,3,4,t)":prob9}
d10 = {"time": time10, "(0,6,4,t)":prob10}
d11 = {"time": time11, "(0,5,3,t)":prob11}
d12 = {"time": time12, "(0,4,6,t)":prob12}
d13 = {"time": time13, "(0,3,5,t)":prob13}
df1 = pd.DataFrame(d1)
df2 = pd.DataFrame(d2)
df3 = pd.DataFrame(d3)
df4 = pd.DataFrame(d4)
df5 = pd.DataFrame(d5)
df6 = pd.DataFrame(d6)
df7 = pd.DataFrame(d7)
df8 = pd.DataFrame(d8)
df9 = pd.DataFrame(d9)
df10 = pd.DataFrame(d10)
df11 = pd.DataFrame(d11)
df12 = pd.DataFrame(d12)
df13 = pd.DataFrame(d13)
# graphing dataframe
fig, ax = plt.subplots()
df1.plot(kind = "line", x = "time",y = "(0,5,5,t)",ylim = [.2,.6], ax = ax)
df2.plot(kind = "line", x = "time", y = "(0,4,4,t)",ylim = [.2,.6], ax = ax)
df3.plot(kind = "line", x = "time", y = "(0,3,3,t)",ylim = [.2,.6], ax = ax)
ax.set(title = "Manpower Differentail is 0", ylabel = "Probability the Home Team Wins")
fig1, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (12,6))
df4.plot(kind = "line", x = "time", y = "(0,6,5,t)",ylim = [.2,.6], ax = ax1)
df5.plot(kind = "line", x = "time", y = "(0,5,4,t)",ylim = [.2,.6], ax = ax1)
df6.plot(kind = "line", x = "time", y = "(0,4,3,t)",ylim = [.2,.6], ax = ax1)
ax1.set(title = "Manpower Differentail is 1" , ylabel = "Probability the Home Team Wins")
df7.plot(kind = "line", x = "time", y = "(0,5,6,t)",ylim = [.2,.6], ax = ax2)
df8.plot(kind = "line", x = "time", y = "(0,4,5,t)",ylim = [.2,.6], ax = ax2)
df9.plot(kind = "line", x = "time", y = "(0,3,4,t)",ylim = [.2,.6],ax = ax2)
ax2.set(title = "Manpower Differentail is -1", ylabel = "Probability the Home Team Wins")
fig2, (ax3, ax4) = plt.subplots(nrows = 1, ncols = 2, figsize = (12,6))
df10.plot(kind = "line", x = "time", y = "(0,6,4,t)",ylim = [.2,.6], ax = ax3)
df11.plot(kind = "line", x = "time", y = "(0,5,3,t)",ylim = [.2,.6], ax = ax3)
ax3.set(title = "Manpower Differentail is 2", ylabel = "Probability the Home Team Wins")
df12.plot(kind = "line", x = "time", y = "(0,4,6,t)",ylim = [.2,.6], ax = ax4)
df13.plot(kind = "line", x = "time", y = "(0,3,5,t)",ylim = [.2,.6], ax = ax4)
ax4.set(title = "Manpower Differentail is -2",  ylabel = "Probability the Home Team Wins")
# Out:
# [Text(0.5, 1.0, 'Manpower Differentail is -2'),
#  Text(0, 0.5, 'Probability the Home Team Wins')]

# %%
# Attempt to Filter data to same manpower differential
# I am not sure if this worked
df_mandiff = df.groupby(by = ["Manpower Diff"])[["TransitionState", "time"]]
df_mandiff.head()
# Out:
#       TransitionState  time
# 0               0,5,5     0
# 1               0,5,5    74
# 2               0,4,5   383
# 3               0,4,5   396
# 4               0,3,5   438
# 5              -1,4,5   481
# 6              -1,4,5   539
# 7              -1,4,4   603
# 8               0,4,4   608
# 9               0,5,4   678
# 10              0,5,4   692
# 11              0,5,5   723
# 14              1,5,4   859
# 15              1,5,4   872
# 21              1,4,5  1246
# 22              1,4,5  1255
# 43              0,4,3  2045
# 52             -1,5,4  2350
# 116             1,3,5  3387
# 117             1,3,5  3407
# 118             1,3,5  3443
# 176            -1,6,4  3514
# 177            -1,6,4  3554
# 210            -1,5,3  2615
# 213            -1,5,3  2733
# 2462            6,5,3  3257
# 6629            0,4,6  3532
# 7867            0,5,3  1043
# 8182           -7,3,5  2731
# 10754          -1,5,3  1761
# 10757          -1,5,3  1839
# 11593           0,3,5  2230
# ...

# %%
vals = [1,4,6,5,4,7,9,12,14,6]
max_v = max(vals)
min_v = min(vals)
rang = max_v - min_v
thresh1 = rang/3
thresh2 = thresh1 * 2
buckets = dict()
buckets["low"] = []
buckets["med"] = []
buckets["high"] = []
for v in vals:
    if v <= thresh1:
        buckets["low"].append(v)
    elif v <= thresh2:
        buckets["med"].append(v)
    else:
        buckets["high"].append(v)
print(buckets)
for i in buckets.values():
# Out:
# {'low': [1, 4, 4], 'med': [6, 5, 7, 6], 'high': [9, 12, 14]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-14244c0c9321> in <module>
#      18 print(buckets)
#      19 for i in buckets.values():
# ---> 20     print(buckets[i])
#
# TypeError: unhashable type: 'list'

# %%
import pandas as pd
df = pd.read_csv("Subset_Hockey_Data.csv",header = 0)
df.head()
# Out:
#   homeTeamCode awayTeamCode  game_id  time  timeUntilNextEvent  period  team  \
# 0          MTL          TOR    20001     0                   0       1   NaN
# 1          MTL          TOR    20001    74                  74       1  AWAY
# 2          MTL          TOR    20001   383                 309       1  HOME
# 3          MTL          TOR    20001   396                  13       1  AWAY
# 4          MTL          TOR    20001   438                  42       1  HOME
#
#   SOG DIF   stdev         event  ...  Goal Diff  homeEmptyNet  awayEmptyNet  \
# 0        0      0     GAMESTART  ...          0             0             0
# 1       -1      0          MISS  ...          0             0             0
# 2  PENALTY      0  PENALTYSTART  ...          0             0             0
# 3        0      0          SHOT  ...          0             0             0
# 4  PENALTY      0  PENALTYSTART  ...          0             0             0
#
# ...

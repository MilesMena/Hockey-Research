# %%
import matplotlib.pyplot as plt
y = [0.5
,0.997476408763366
,0.992659747623913
,0.499896621738633
,0.015182646871529
,0.000589886650734
,8.075309691e-06
,6.77700405e-07
,1.1669931718e-05
,1.6157415514e-05
,1.5343377329e-05
,2.6274298267e-05
,0.001119485951207
,0.000194951402443
,0.000529746505755
,0.001315533670322
,0.001447418135343
,0.001476374021913
,0.042031896786847
,0.002080812858028
,0.002128015078903
,0.005411358385164
,0.058049792473192
,0.025269704936008
,0.018809283185463
,0.053807184527784
,0.49405633057413]

x = [0.0
,117.0
,301.0
,309.0
,701.0
,1213.0
,1242.0
,1291.0
,1411.0
,1432.0
,1552.0
,1697.0
,1707.0
,1842.0
,1842.0
,1962.0
,1962.0
,2085.0
,2120.0
,2395.0
,2532.0
,2598.0
,2626.0
,2707.0
,2718.0
,2827.0
,2861.0]

#https://www.geeksforgeeks.org/time-series-plot-or-line-plot-with-pandas/?ref=rp

plt.scatter(x, y)
plt.show()
plt.plot(x,y ,title = "Tor vs. ")
#plt.plot(p,q)

# The spikes and dips are goals by the home team then the away team. 
# Notice that the first spike is almost 100 percent win rate, which
# quickly moves to almost 100 percent lose rate. 
# Losing from one point is the same win probability as losing by 
# three points.

# %%
import matplotlib.pyplot as plt
y = [0.5,
0.506511612438132
,0.499834130063137
,0.484036710217302
,0.003523600763097
,0.017032401357948
,0.023300338005404
,0.009198733135551
,0.005636916452852
,0.024296345753448
,0.000636738636347
,0.00071011910361
,0.002069026597884
,0.000830026094059
,0.00104160785954
,0.040393232802169
,0.001876502354553
,0.000345500950409
,0.000030589437356
,0.000393231060119
,0.002135958325046
,0.000487459610072
,0.02677774560308
,0.002607664109937
,0.003008213653874
,9.4519116396e-05
,0.000138930538148
,0.003229514592451
,0.003471880993137
,0.00013187161952
,0.000178937583738
,0.000149030974246
,0.004213247629817]

x = [0.0
,274.0
,394.0
,754.0
,759.0
,791.0
,977.0
,1035.0
,1097.0
,1155.0
,1263.0
,1422.0
,1522.0
,1542.0
,1642.0
,2026.0
,2262.0
,2303.0
,2310.0
,2423.0
,2430.0
,2637.0
,2757.0
,2824.0
,2944.0
,2958.0
,3074.0
,3171.0
,3194.0
,3339.0
,3372.0
,3492.0
,3570.0]


p = [0.0
,21.0
,221.0
,759.0
,1142.0
,1188.0
,1367.0
,1549.0
,1657.0
,2262.0
,2321.0
,2370.0
,2472.0
,2511.0
,2758.0
,2940.0
,2958.0
,3171.0
,3436.0
,3569.0]

q = [0.5
,0.501668512307833
,0.513773354595645
,0.215407600517748
,0.265496058289334
,0.080320686722212
,0.081942328052062
,0.129259975979969
,0.333513401236088
,0.187082513061183
,0.147513162542448
,0.162767080912991
,0.156978263371956
,0.205110229760619
,0.174275549286621
,0.101698803892741
,0.137044882804465
,0.248667954545463
,0.164382300143694
,0.272531774372408]

#https://www.geeksforgeeks.org/time-series-plot-or-line-plot-with-pandas/?ref=rp

plt.scatter(x, y)
plt.show()
fig, ax = plt.subplots()
plt.plot(x,y)

ax.set(xlabel = "Time (Seconds)", ylabel = "Probability of Home Team Win")
plt.plot(p,q)

# The first huge dip is an away team goal.
# At time 2026, there is a minor rise. This is a home team goal
# and this shows our model incorporates momentum?
